# %% [markdown]
# Explore images

# %%
import glob
from PIL import Image
import torch
import torchvision
import numpy as np
import matplotlib
import cv2
from IPython.display import display

# %%
label_img_path = "/home/hice1/athalanki3/scratch/DeepLearningProject/FloodNet/ColorMasks-FloodNetv1.0/ColorMasks-TrainSet/6334_lab.png"
label_im = Image.open(label_img_path)
display(label_im)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>

# %%
label = np.array(label_im)
